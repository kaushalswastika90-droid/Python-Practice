# %%
n = 5

i = n
while i >= 1:
    j = n
    while j >= n - i + 1:
        print("*", end=" ")
        j -= 1
    print()
    i -= 1
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n = 5

i = n
while i >= 1:
    j = n
    while j >= i:
        print("*", end=" ")
        j -= 1
    print()
    i -= 1
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
for i in range(n, 0, -1):
    print("* " * i)
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(1, n + 1):
    print("* " * i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n = 10

for i in range(1, n + 1):
    print(" " * (n - i) + "* " * i)
# Out:
#          *
#         * *
#        * * *
#       * * * *
#      * * * * *
#     * * * * * *
#    * * * * * * *
#   * * * * * * * *
#  * * * * * * * * *
# * * * * * * * * * *

# %%
n = 10

for i in range(1, n + 1):
    print(" " * (n - i) + "* " * i)

for i in range(n-1,0,-1):
  print(" " * (n - i) + "* " * i)
# Out:
#          *
#         * *
#        * * *
#       * * * *
#      * * * * *
#     * * * * * *
#    * * * * * * *
#   * * * * * * * *
#  * * * * * * * * *
# * * * * * * * * * *
#  * * * * * * * * *
#   * * * * * * * *
#    * * * * * * *
#     * * * * * *
#      * * * * *
#       * * * *
#        * * *
#         * *
#          *

# %%
n = 10
for i in range(1, n + 1):
  if i==1:
    print(" " * (n - 1) + "*")
  elif i==n:
    print("* "*(2*n-1))
  else:
    print(" " * (n - i) + "* "+" " * (2*i - 3)+"* ")
# Out:
#          *
#         *  *
#        *    *
#       *      *
#      *        *
#     *          *
#    *            *
#   *              *
#  *                *
# * * * * * * * * * * * * * * * * * * *
